# %% [markdown]
# <h1 style="color:blue;text-align:center;">Lab 1 - Scraping and NLP Pipeline</h1>
#
# <hr style="border:2px solid blue;">
#
# <h3 style="color:blue;">Realised by: <strong style="color:black;">Ouahid Mariyam</strong></h3>
#
#
# <h3 style="color:blue;">Guided by: <strong style="color:black;">Pr . ELAACHAk LOTFI</strong></h3>
#
#
# <p><strong>Objective :</strong> The main purpose behind this lab is to get familiar with Scraping and NLP
#  Pipeline.</p>
#
#
#
#  <p>This lab effectively combines data scraping with NLP techniques to collect, preprocess, and analyze text data from the web. The scraping process enables the extraction of relevant information from web pages, while the NLP pipeline facilitates text processing and analysis for various applications such as text classification, sentiment analysis, and information extraction. Overall, this lab provides practical experience in utilizing web scraping and NLP techniques for data collection and analysis tasks. </p>

# %% [markdown]
# #       Summary:
#
# 1. [Data Loading](#data-loading)
# 2. [NLP Pipeline](#nlp-pipeline)
#     1. [Text Cleaning](#text-cleaning)
#     2. [Tokenization](#tokenization)
#     3. [Stop words](#stop-words)
#     4. [Discretization](#discretization)
#     5. [Normalization](#nor)
#     6. [ Stemming and Lemmatization](#SL)
# 3. [Parts of Speech (POS)](#part)
# 4. [Named Entity Recognition(NER)](#ner)
# 5. [Lab Reflection](#lab)

# %% [markdown]
# ## 1. Data Loading <a id='data-loading'></a>

# %%
import requests
from bs4 import BeautifulSoup
import pymongo
import pandas as pd

# %%
def scrape_recipe_data(url):
    titles = []
    properties = []
    chefs = []
    links = []
    ingredients = []
    recipes = []

    # Retrieve the content of the web page
    result = requests.get(url)
    src = result.content
    soup = BeautifulSoup(src, "lxml")

    # Find the elements on the web page containing the data
    titles_tags = soup.find_all("h2", {"class": "mb-0 semibold-font"})
    properties_tags = soup.find_all("div", {"class": "tabkha-details rounded-pill py-1 me-1 medium-font"})
    chef_tags = soup.find_all("h3", {"class": "pt-5 recipe-chef-name medium-font"})
    div_tags = soup.find_all("a", {"class": "recipe-real-image"})

    # Loop to extract and store the data
    for i in range(len(titles_tags)):
        titles.append(titles_tags[i].text.strip())
        properties.append(properties_tags[i].text.strip())
        # Check if chef tag exists before accessing its text
        if i < len(chef_tags):
            chefs.append(chef_tags[i].text.strip())
        else:
            chefs.append("Unknown Chef")
        links.append(div_tags[i].attrs['href'])

    # Loop to extract ingredients and recipes from each recipe's page
    for link in links:
        result = requests.get(link)
        src = result.content
        soup = BeautifulSoup(src, "lxml")
        ingredients_tags = soup.find("div", {"class": "row px-0 px-lg-3 ingredients"})
        if ingredients_tags:
            ingredients.append(ingredients_tags.text.strip())
        else:
            ingredients.append("Ingredients not available")
        recipes_tags = soup.find("div", {"class": "row px-0 px-lg-3 preparationWay"})
        if recipes_tags:
            recipes.append(recipes_tags.text.strip())
        else:
            recipes.append("Recipes not available")

    return titles, properties, chefs, ingredients, recipes

# %%
def save_to_mongodb(data):
    client = pymongo.MongoClient("mongodb://localhost:27017")
    db = client["myScraping"]
    collection = db["mydb"]
    for i in range(len(data[0])):
        recipe = {
            "title": data[0][i],
            "properties": data[1][i],
            "chef": data[2][i],
            "ingredients": data[3][i],
            "recipes": data[4][i]
        }
        collection.insert_one(recipe)
    client.close()

# %%
# Scrape and save cake recipes
cake_data = scrape_recipe_data("https://www.fatafeat.com/recipes-list/207106-%D9%83%D9%8A%D9%83")
save_to_mongodb(cake_data)

# Scrape and save pizza recipes
pizza_data = scrape_recipe_data("https://www.fatafeat.com/search?term=%D8%A8%D9%8A%D8%AA%D8%B2%D8%A7")
save_to_mongodb(pizza_data)

# Scrape and save cookies recipes
cookies_data = scrape_recipe_data("https://www.fatafeat.com/recipes-list/207104-%D9%83%D9%88%D9%83%D9%8A%D8%B2")
save_to_mongodb(cookies_data)

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017")
db = client["myScraping"]
collection = db["mydb"]

# %%
# Fetch data from MongoDB
cursor = collection.find()

# %%
# Convert the cursor to a list of dictionaries
data = list(cursor)

# %%
# Create a DataFrame from the data
df = pd.DataFrame(data)

# %%
# Close the MongoDB connection
client.close()

# %%
# Display the DataFrame
df
# Out:
#                          _id                           title properties  \
# 0   66135d7bccad4da1905a3eb0             تشيز كيك قليل الدسم       سهلة
# 1   66135d7bccad4da1905a3eb1               كيك الموز بالتوفي       سهلة
# 2   66135d7bccad4da1905a3eb2              كيك ماربل بالكاكاو       سهلة
# 3   66135d7bccad4da1905a3eb3                كيك القرع واللوز       سهلة
# 4   66135d7bccad4da1905a3eb4                  كعكة‭ ‬الجواهر       سهلة
# 5   66135d7bccad4da1905a3eb5           كعكة‭ ‬البلاك‭ ‬فورست       سهلة
# 6   66135d7bccad4da1905a3eb6  مخبوز البانوفى بالموز ( كيك...     متوسطة
# 7   66135d7bccad4da1905a3eb7                     كيك‭ ‬التمر       سهلة
# 8   66135d7bccad4da1905a3eb8                     كيكة السميد       سهلة
# 9   66135d7bccad4da1905a3eb9        كاب كيك بشوكولاتة فيريرو     متوسطة
# 10  66135d7bccad4da1905a3eba                  سفوف بالزعفران       سهلة
# 11  66135d7bccad4da1905a3ebb        كيك طبقات مع آيس كريم...     متوسطة
# 12  66135d7bccad4da1905a3ebc                  كيك مثل مابدّك       سهلة
# 13  66135d7bccad4da1905a3ebd                       كيندا كيك     متقدمة
# 14  66135d7bccad4da1905a3ebe     كب كيك بالفستق الحلبي مع...       سهلة
# 15  66135d9dccad4da1905a3ec0                    بيتزا التوست       سهلة
# 16  66135d9dccad4da1905a3ec1                    بيتزا الدجاج     متوسطة
# 17  66135d9dccad4da1905a3ec2              بيتزا الأم العربية     متوسطة
# 18  66135d9dccad4da1905a3ec3             بيتزا البحر المتوسط       سهلة
# 19  66135d9dccad4da1905a3ec4        بيتزا دجاج كاجون وصوص...       سهلة
# 20  66135d9dccad4da1905a3ec5                  بيتزا مارغريتا       سهلة
# 21  66135d9dccad4da1905a3ec6   بيتزا البصل المكرمل والأنشوفة       سهلة
# 22  66135d9dccad4da1905a3ec7         بيتزا الهليون والريكوتا       سهلة
# 23  66135d9dccad4da1905a3ec8             بيتزا بالخبز العربي       سهلة
# 24  66135d9dccad4da1905a3ec9            بيتزا جيوب البيبروني       سهلة
# 25  66135d9dccad4da1905a3eca                 بيتزا الكاساديا       سهلة
# 26  66135d9dccad4da1905a3ecb   كنافة ذهبية بالمانجو والكريمه       سهلة
# 27  66135d9dccad4da1905a3ecc                    فطيرة الكفتة       سهلة
# 28  66135d9dccad4da1905a3ecd             بيتزا دبل تشيز برجر       سهلة
# 29  66135d9dccad4da1905a3ece               مناقيش حلوم وفلفل       سهلة
# 30  66135d9dccad4da1905a3ecf                   رقاقات الجبنة     متوسطة
# 31  66135d9dccad4da1905a3ed0   تغطية الكعكة بطبقة الفندان...       سهلة
# 32  66135d9dccad4da1905a3ed1                   لفائف البيتزا       سهلة
# 33  66135d9dccad4da1905a3ed2          حشو وتغطية طبقات الكيك       سهلة
# 34  66135d9dccad4da1905a3ed3                    كوكيز الزبدة     متوسطة
# 35  66135db5ccad4da1905a3ed5  كوكيز‭ ‬رقائق‭ ‬الشوكولاتة‭...       سهلة
# 36  66135db5ccad4da1905a3ed6                   كوكيز قوس قزح     متوسطة
# 37  66135db5ccad4da1905a3ed7    كوكيز زبدة الفول السوداني...     متوسطة
# 38  66135db5ccad4da1905a3ed8       كوكيز الشيكولاتة بالنعناع     متوسطة
# 39  66135db5ccad4da1905a3ed9                   كوكيز البيتزا     متوسطة
# 40  66135db5ccad4da1905a3eda           كوكيز بالزبدة والبندق       سهلة
# 41  66135db5ccad4da1905a3edb     سكونز بالجوز وتوت العليق...       سهلة
# 42  66135db5ccad4da1905a3edc                       كوكيز صحي       سهلة
# 43  66135db5ccad4da1905a3edd              كوكيز بقطرات التمر       سهلة
# 44  66135db5ccad4da1905a3ede                     كوكيز التمر       سهلة
# 45  66135db5ccad4da1905a3edf         سكون البارميزان الصغيرة       سهلة
# 46  66135db5ccad4da1905a3ee0                  كوكيز الزنجبيل       سهلة
# 47  66135db5ccad4da1905a3ee1                    كوكيز وكريمة       سهلة
# 48  66135db5ccad4da1905a3ee2              كوكيز التمر اللينة       سهلة
# 49  66135db5ccad4da1905a3ee3           كوكيز بالأوريو والكرز       سهلة
#
#              chef                                        ingredients  \
# 0   ليلى فتح الله  180 \n\n\nجرام بسكويت عادي\n\n\n\n\n\n\n 90 \n...
# 1     منال العالم  1 1/2 \n\n\nكوب دقيق\n\n\n\n\n\n\n 1 \n\n\nملع...
# 2     منال العالم  3 \n\n\nكوب دقيق\n\n\n\n\n\n\n 3 \n\n\nملعقة ص...
# 3    وصفات فتافيت  125 \n\n\nجرام دقيق اللوز\n\n\n\n\n\n\n 25 \n\...
# 4    وصفات فتافيت  0 \n\n\nعبوة تحتوي على 4 أنواع مختلفة من الجيل...
# 5    وصفات فتافيت  200 \n\n\nجم الدقيق\n\n\n\n\n\n\n 50 \n\n\nجم ...
# 6           أفنان  190 \n\n\nجرام دقيق\n\n\n\n\n\n\n 0 \n\n\nملعق...
# 7    وصفات فتافيت  2 \n\n\n بيضة\n\n\n\n\n\n\n 3 \n\n\n أكواب من ...
# 8     منال العالم  1/2 \n\n\nكوب دقيق\n\n\n\n\n\n\n 2 \n\n\nملعقة...
# 9    وصفات فتافيت  125 \n\n\nجرام زبدة\n\n\n\n\n\n\n 1 1/2 \n\n\n...
# 10   وصفات فتافيت  320 \n\n\nجرام سميد\n\n\n\n\n\n\n 175 \n\n\nجر...
# 11   وصفات فتافيت  125 \n\n\nجرام زبدة\n\n\n\n\n\n\n 1 1/2 \n\n\n...
# 12    منال العالم  2 1/2 \n\n\nكوب دقيق\n\n\n\n\n\n\n 1 \n\n\nملع...
# 13          أفنان  6 \n\n\n بياض بيض\n\n\n\n\n\n\n 3/4 \n\n\nكوب ...
# 14   وصفات فتافيت  120 \n\n\nجرام معجون الفستق الحلبي\n\n\n\n\n\n...
# 15   وصفات فتافيت  8 \n\n\nقطع توست\n\n\n\n\n\n\n 1 \n\n\nكوب لبن...
# 16   وصفات فتافيت  - \n\n\n عجينة بيتزا جاهزة\n\n\n\n\n\n\n - \n\...
# 17   وصفات فتافيت  1 \n\n\nكوب من الماء الدافئ\n\n\n\n\n\n\n 1 \n...
# 18   وصفات فتافيت  - \n\n\n لعجينة البيتزا\n\n\n\n\n\n\n 1 \n\n\n...
# 19   وصفات فتافيت  - \n\n\n عجينة البيتزا\n\n\n\n\n\n\n 2 \n\n\nم...
# 20   وصفات فتافيت  - \n\n\n طحين الذرة\n\n\n\n\n\n\n - \n\n\n طما...
# 21   وصفات فتافيت  - \n\n\n عجينة البيتزا:\n\n\n\n\n\n\n 3 \n\n\n...
# 22   وصفات فتافيت  - \n\n\n لعجين البيتزا:\n\n\n\n\n\n\n 450 \n\n...
# 23   وصفات فتافيت  2 \n\n\nشريحة خبز عربي بالقمح الكامل\n\n\n\n\n...
# 24   وصفات فتافيت  1 \n\n\nشريحة باف باستري\n\n\n\n\n\n\n 1 \n\n\...
# 25   وصفات فتافيت  1 \n\n\nشريحة تورتيلا القمح\n\n\n\n\n\n\n 3 \n...
# 26   وصفات فتافيت  250 \n\n\nجرام عجينة كنافة جاهزة\n\n\n\n\n\n\n...
# 27   وصفات فتافيت  450 \n\n\nجم عجينة بيتزا\n\n\n\n\n\n\n 2 \n\n\...
# 28   وصفات فتافيت  250 \n\n\nجم طحين\n\n\n\n\n\n\n 1 \n\n\nملعقة ...
# 29   دعد أبو جابر  2 \n\n\nملعقة كبيرة زيت زيتون\n\n\n\n\n\n\n 1 ...
# 30   وصفات فتافيت  - \n\n\n العجين:\n\n\n\n\n\n\n 5 \n\n\nكوب طحي...
# 31   وصفات فتافيت  - \n\n\n أقراص سكرية بيضاء\n\n\n\n\n\n\n - \n\...
# 32    سهى عبدالله  1 \n\n\nكوب أوراق الريحان\n\n\n\n\n\n\n 2 \n\n...
# 33   Unknown Chef  - \n\n\n أدوات تشكيل الكعكة\n\n\n\n\n\n\n - \n...
# 34   Unknown Chef  5 \n\n\nكوب طحين متعدد الاستعمالات\n\n\n\n\n\n...
# 35   وصفات فتافيت  1/2 \n\n\nكوب الدقيق\n\n\n\n\n\n\n 1/2 \n\n\nك...
# 36          أفنان  0 \n\n\nكوب نصف سكر\n\n\n\n\n\n\n 2 \n\n\nملعق...
# 37          أفنان  0 \n\n\nكوب سكر أبيض\n\n\n\n\n\n\n 0 \n\n\nكوب...
# 38          أفنان  0 \n\n\nكوب زبدة\n\n\n\n\n\n\n 3/4 \n\n\nكوب س...
# 39          أفنان  0 \n\n\nكوب نصف سكر\n\n\n\n\n\n\n 0 \n\n\nملعق...
# 40   وصفات فتافيت  250 \n\n\nجرام طحين متعدد الاستعمالات\n\n\n\n\...
# 41  ليلى فتح الله  2 \n\n\nكوب دقيق اللوز\n\n\n\n\n\n\n 1/2 \n\n\...
# 42  ليلى فتح الله  1 \n\n\nكوب شوفان\n\n\n\n\n\n\n 1 \n\n\nكوب لو...
# 43   وصفات فتافيت  1/2 \n\n\nكوب زبد\n\n\n\n\n\n\n 1 \n\n\nكوب سك...
# 44   وصفات فتافيت  1 1/4 \n\n\nكوب زبد\n\n\n\n\n\n\n 4 1/2 \n\n\n...
# 45    سلمى سليمان  2 \n\n\nملعقة زبدة\n\n\n\n\n\n\n 2 \n\n\nكوب د...
# 46   وصفات فتافيت  6 \n\n\nملاعق دقيق\n\n\n\n\n\n\n 3 \n\n\nملاعق...
# 47   وصفات فتافيت  3/4 \n\n\nكوب كوكيز الشوكولاتة المفتتة\n\n\n\n...
# 48   وصفات فتافيت  2 \n\n\nكوب تمر\n\n\n\n\n\n\n 2 \n\n\nكوب لوز\...
# 49   Unknown Chef  110 \n\n\nجرام زبدة\n\n\n\n\n\n\n 75 \n\n\nجرا...
#
#                                               recipes
# 0   1\n\nيحمى الفرن إلى 160 درجة مئوية (بدون مروحة...
# 1   1\n\nيثبت الرف الشبكي في وسط الفرن. يسخن الفرن...
# 2   1\n\nيحضر قالب ذو فتحة من الوسط سعة 12 كوب. يد...
# 3   1\n\nيخلط دقيق اللوز والطحين متعدد الاستعمالات...
# 4                               Recipes not available
# 5   1\n\nتُخفق‭ ‬الزبدة‭ ‬مع‭ ‬السكر‭ ‬حتى‭ ‬يتكون...
# 6   1\n\nلعمل الصوص : يرفع السكر مع الماء على النا...
# 7   1\n\nتُنخل‭ ‬المكونات‭ ‬الجافة‭ ‬معاً‭ ‬فيما‭ ...
# 8   1\n\nيسخن الفرن لدرجة حرارة 180. يحضر قالب مست...
# 9   1\n\nيخفق البيض والسكر والفانيليا حتى يصبح الم...
# 10  1\n\nيخلط السميد والطحين والكركم والزعفران وال...
# 11  1\n\nتخفق الزبدة مع السكر والفانيليا حتى يصبح ...
# 12  1\n\nيسخن الفرن لدرجة حرارة 180.\n\n\n\n\n\n2\...
# 13  1\n\nيسخن الفرن على درجة حرارة 135 درجة مئوية ...
# 14  1\n\nيضرب في وعاء معجون الفستق الحلبي والجلوكو...
# 15  1\n\nفي وعاء عميق نقوم بوضع اللبنة والحليب ونخ...
# 16  1\n\nيسخن الفرن إلى 180 درجة مئوية. غلف صينية ...
# 17  1\n\nنقطع البصل إلى قطع صغيرة ثم فى وعاء متوسط...
# 18  1\n\nلتحضير العجين: نذيب الخميرة في الماء الدا...
# 19  1\n\nتُّذوب الخميرة في الماء الدافئ وتترك لمدة...
# 20  1\n\nتذاب الخميرة في الماء الدافئ وتترك لمدة 3...
# 21  1\n\nتذاب الخميرة في الماء الدافئ و تترك لمدة ...
# 22  1\n\n يُمزج الطحين و زيت الزيتون والخميرة والس...
# 23  1\n\nندهن الخبز بصوص البيتزا\n\n\n\n\n\n2\n\nن...
# 24  1\n\nتقطع عجينة الباف باستري إلى مستطيلات وتوض...
# 25  1\n\nندهن شريحة التورتيلا بصوص البيتزا ونضع فو...
# 26  1\n\nنضع الزبدة المذابة على عجين الكنافة ببطء،...
# 27  1\n\nتقطع عجينة البيتزا إلى نصفين\n\n\n\n\n\n2...
# 28  1\n\nنضع الدقيق والخميرة و 1 ملعقة صغيرة من ال...
# 29  1\n\nتسخن ملعقة كبيرة من زيت الزيتون في مقلاة ...
# 30  1\n\nتعجن مكًونات العجينة بشكل جيدٍ جداً، ولمد...
# 31                              Recipes not available
# 32  1\n\nيقطع كل رغيف بيتا إلى مثلثات.\n\n\n\n\n\n...
# 33  1\n\nنستخدم دائمًا الكعكة باردة ، وتحفظ او تتر...
# 34  1\n\nيسخن الفرن على حرارة 180 درجة مئوية. تبطن...
# 35  1\n\nيُخلط‭ ‬نوعي‭ ‬الدقيق‭ ‬والبيكنج‭ ‬صودا‭ ...
# 36  1\n\nيخفق السكر البودرة مع السكر الأبيض و المل...
# 37  1\n\nفي وعاء على النار يخلط السكر مع الشربات ا...
# 38  1\n\nلعمل الكوكيز : تخلط كل المكونات الجافة جي...
# 39  1\n\nلعمل الصوص : في وعاء متوسط العمق على النا...
# 40  1\n\nيخلط الطحين والقرفة والملح والسكر في محضر...
# 41  1\n\nفي محضرة الطعام، يضرب دقيق اللوز مع الباك...
# 42  1\n\nتخلط كل المقادير معاً.\n\n\n\n\n\n2\n\nيو...
# 43  1\n\nيغلى التمر والماء والسكر معاً، ثم تخفض در...
# 44  1\n\nفي وعاء خلاط كهربائي يوضع الزبد والدقيق و...
# 45  1\n\nيسخن الفرن إلى درجة حرارة 350 فهرنهايت (1...
# 46  1\n\nينخل الدقيق مع الملح والفلفل والزنجبيل.\n...
# 47  1\n\nيصب الحليب في قدر ويوضع على النار إلى أن ...
# 48  1\n\nتُخلط كل المكونات معاً في وعاء.\n\n\n\n\n...
# 49  1\n\nتخفق الزبدة، وسكر الكاسترد والسكر البني، ...

# %% [markdown]
# ## 2. NLP Pipeline <a id='nlp-pipeline'></a>

# %% [markdown]
# ### 2.1 Text Cleaning <a id='text-cleaning'></a>

# %%
import re

# Arabic Text Cleaning
def clean_arabic_text(text):
    # Remove non-Arabic characters and extra spaces
    cleaned_text = re.sub(r'[^\u0621-\u064A\s]', '', text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    return cleaned_text.strip()

# Apply cleaning to each column that contains text
df['title'] = df['title'].apply(clean_arabic_text)
df['properties'] = df['properties'].apply(clean_arabic_text)
df['ingredients'] = df['ingredients'].apply(clean_arabic_text)
df['recipes'] = df['recipes'].apply(clean_arabic_text)

# %%
# Display the DataFrame
df
# Out:
#                          _id                          title properties  \
# 0   66135d7bccad4da1905a3eb0            تشيز كيك قليل الدسم       سهلة
# 1   66135d7bccad4da1905a3eb1              كيك الموز بالتوفي       سهلة
# 2   66135d7bccad4da1905a3eb2             كيك ماربل بالكاكاو       سهلة
# 3   66135d7bccad4da1905a3eb3               كيك القرع واللوز       سهلة
# 4   66135d7bccad4da1905a3eb4                   كعكة الجواهر       سهلة
# 5   66135d7bccad4da1905a3eb5              كعكة البلاك فورست       سهلة
# 6   66135d7bccad4da1905a3eb6      مخبوز البانوفى بالموز كيك     متوسطة
# 7   66135d7bccad4da1905a3eb7                      كيك التمر       سهلة
# 8   66135d7bccad4da1905a3eb8                    كيكة السميد       سهلة
# 9   66135d7bccad4da1905a3eb9       كاب كيك بشوكولاتة فيريرو     متوسطة
# 10  66135d7bccad4da1905a3eba                 سفوف بالزعفران       سهلة
# 11  66135d7bccad4da1905a3ebb          كيك طبقات مع آيس كريم     متوسطة
# 12  66135d7bccad4da1905a3ebc                  كيك مثل مابدك       سهلة
# 13  66135d7bccad4da1905a3ebd                      كيندا كيك     متقدمة
# 14  66135d7bccad4da1905a3ebe       كب كيك بالفستق الحلبي مع       سهلة
# 15  66135d9dccad4da1905a3ec0                   بيتزا التوست       سهلة
# 16  66135d9dccad4da1905a3ec1                   بيتزا الدجاج     متوسطة
# 17  66135d9dccad4da1905a3ec2             بيتزا الأم العربية     متوسطة
# 18  66135d9dccad4da1905a3ec3            بيتزا البحر المتوسط       سهلة
# 19  66135d9dccad4da1905a3ec4          بيتزا دجاج كاجون وصوص       سهلة
# 20  66135d9dccad4da1905a3ec5                 بيتزا مارغريتا       سهلة
# 21  66135d9dccad4da1905a3ec6  بيتزا البصل المكرمل والأنشوفة       سهلة
# 22  66135d9dccad4da1905a3ec7        بيتزا الهليون والريكوتا       سهلة
# 23  66135d9dccad4da1905a3ec8            بيتزا بالخبز العربي       سهلة
# 24  66135d9dccad4da1905a3ec9           بيتزا جيوب البيبروني       سهلة
# 25  66135d9dccad4da1905a3eca                بيتزا الكاساديا       سهلة
# 26  66135d9dccad4da1905a3ecb  كنافة ذهبية بالمانجو والكريمه       سهلة
# 27  66135d9dccad4da1905a3ecc                   فطيرة الكفتة       سهلة
# 28  66135d9dccad4da1905a3ecd            بيتزا دبل تشيز برجر       سهلة
# 29  66135d9dccad4da1905a3ece              مناقيش حلوم وفلفل       سهلة
# 30  66135d9dccad4da1905a3ecf                  رقاقات الجبنة     متوسطة
# 31  66135d9dccad4da1905a3ed0     تغطية الكعكة بطبقة الفندان       سهلة
# 32  66135d9dccad4da1905a3ed1                  لفائف البيتزا       سهلة
# 33  66135d9dccad4da1905a3ed2         حشو وتغطية طبقات الكيك       سهلة
# 34  66135d9dccad4da1905a3ed3                   كوكيز الزبدة     متوسطة
# 35  66135db5ccad4da1905a3ed5         كوكيز رقائق الشوكولاتة       سهلة
# 36  66135db5ccad4da1905a3ed6                  كوكيز قوس قزح     متوسطة
# 37  66135db5ccad4da1905a3ed7      كوكيز زبدة الفول السوداني     متوسطة
# 38  66135db5ccad4da1905a3ed8      كوكيز الشيكولاتة بالنعناع     متوسطة
# 39  66135db5ccad4da1905a3ed9                  كوكيز البيتزا     متوسطة
# 40  66135db5ccad4da1905a3eda          كوكيز بالزبدة والبندق       سهلة
# 41  66135db5ccad4da1905a3edb       سكونز بالجوز وتوت العليق       سهلة
# 42  66135db5ccad4da1905a3edc                      كوكيز صحي       سهلة
# 43  66135db5ccad4da1905a3edd             كوكيز بقطرات التمر       سهلة
# 44  66135db5ccad4da1905a3ede                    كوكيز التمر       سهلة
# 45  66135db5ccad4da1905a3edf        سكون البارميزان الصغيرة       سهلة
# 46  66135db5ccad4da1905a3ee0                 كوكيز الزنجبيل       سهلة
# 47  66135db5ccad4da1905a3ee1                   كوكيز وكريمة       سهلة
# 48  66135db5ccad4da1905a3ee2             كوكيز التمر اللينة       سهلة
# 49  66135db5ccad4da1905a3ee3          كوكيز بالأوريو والكرز       سهلة
#
#              chef                                        ingredients  \
# 0   ليلى فتح الله  جرام بسكويت عادي جرام زبدة جرام جبنة الكريم جر...
# 1     منال العالم  كوب دقيق ملعقة كبيرة بيكنج باودر ملعقة صغيرة م...
# 2     منال العالم  كوب دقيق ملعقة صغيرة بيكنج باودر ملعقة صغيرة م...
# 3    وصفات فتافيت  جرام دقيق اللوز جرام طحين متعدد الاستعمالات مل...
# 4    وصفات فتافيت  عبوة تحتوي على أنواع مختلفة من الجيلاتين المنك...
# 5    وصفات فتافيت  جم الدقيق جم الكاكاو البودرة ملعقة صغيرة البيك...
# 6           أفنان  جرام دقيق ملعقة صغيرة و نصف بيكنج باودر جرام ز...
# 7    وصفات فتافيت  بيضة أكواب من الدقيق ملعقة صغيرة برش الليمون م...
# 8     منال العالم  كوب دقيق ملعقة صغيرة بيكنج باودر كوب سميد ناعم...
# 9    وصفات فتافيت  جرام زبدة كوب سكر ملعقة صغيرة فانيليا حبة بيض ...
# 10   وصفات فتافيت  جرام سميد جرام طحين متعدد الإستعمالات ملعقة كب...
# 11   وصفات فتافيت  جرام زبدة كوب سكر ملعقة صغيرة فانيليا حبة بيض ...
# 12    منال العالم  كوب دقيق ملعقة كبيرة بيكنج باودر ملعقة صغيرة م...
# 13          أفنان  بياض بيض كوب و سكر ابيض ملعقة كبيرة نشاء كوب ك...
# 14   وصفات فتافيت  جرام معجون الفستق الحلبي جرام شراب الذرة بياض ...
# 15   وصفات فتافيت  قطع توست كوب لبنة مالعق كبيرة حليب كوب معجون ط...
# 16   وصفات فتافيت  عجينة بيتزا جاهزة كوب ربع نور مايونيز فصوص ثوم...
# 17   وصفات فتافيت  كوب من الماء الدافئ ملعقة كبيرة السكر ملعقة كب...
# 18   وصفات فتافيت  لعجينة البيتزا كوب طحين قمح كوب طحين ذرة ملعقة...
# 19   وصفات فتافيت  عجينة البيتزا ملعقة كبيرة زيت زيتون ملاعق كبير...
# 20   وصفات فتافيت  طحين الذرة طماطم مقطعة موزاريلا مقطعة إلى شرائ...
# 21   وصفات فتافيت  عجينة البيتزا ملاعق كبيرة خميرة ماء دافئ كوب د...
# 22   وصفات فتافيت  لعجين البيتزا جرام طحين سادة جرام خميرة جافة م...
# 23   وصفات فتافيت  شريحة خبز عربي بالقمح الكامل حبة كوسا ملعقة صغ...
# 24   وصفات فتافيت  شريحة باف باستري كوب صوص مارينارا شريحة بيبرون...
# 25   وصفات فتافيت  شريحة تورتيلا القمح ملعقة صوص البيتزا كوب بيبي...
# 26   وصفات فتافيت  جرام عجينة كنافة جاهزة جرام زبدة ذائبة كوب ماء...
# 27   وصفات فتافيت  جم عجينة بيتزا ملعقة كبيرة زيت زيتون فص ثوم مف...
# 28   وصفات فتافيت  جم طحين ملعقة صغيرة خميرة فورية ملعقة صغيرة سك...
# 29   دعد أبو جابر  ملعقة كبيرة زيت زيتون حبة بصل مقطعة فص ثوم مفر...
# 30   وصفات فتافيت  العجين كوب طحين كوب نشا كوب سمنة نباتية كوب تق...
# 31   وصفات فتافيت  أقراص سكرية بيضاء إبرة الدوران حصيرة السيليكون...
# 32    سهى عبدالله  كوب أوراق الريحان فص ثوم كوب جبنة البارميزان ك...
# 33   Unknown Chef  أدوات تشكيل الكعكة غلاف بلاستيكي مسن سكين أو ق...
# 34   Unknown Chef  كوب طحين متعدد الاستعمالات كوب زبدة غير مملحة ...
# 35   وصفات فتافيت  كوب الدقيق كوب الدقيق كامل القمح ملعقة صغيرة ا...
# 36          أفنان  كوب نصف سكر ملعقة كبيرة سكر بودرة رشة ملح بيضة...
# 37          أفنان  كوب سكر أبيض كوب شربات خفيف كوب زبدة فول سودان...
# 38          أفنان  كوب زبدة كوب سكر أبيض كوب سكر بني بيضة ملعقة ص...
# 39          أفنان  كوب نصف سكر ملعقة كبيرة نشاء كوب نصف عصير انان...
# 40   وصفات فتافيت  جرام طحين متعدد الاستعمالات ملعقة صغيرة قرفة م...
# 41  ليلى فتح الله  كوب دقيق اللوز ملعقة باكينج صودا بيض ملعقة سكر...
# 42  ليلى فتح الله  كوب شوفان كوب لوز كوب بذور السمسم كوب جوز الهن...
# 43   وصفات فتافيت  كوب زبد كوب سكر بني بيضة مخفوقة كوب ماء دافئ م...
# 44   وصفات فتافيت  كوب زبد كوب دقيق عادي ملعقة ملح كوب سكر بودرة ...
# 45    سلمى سليمان  ملعقة زبدة كوب دقيق تخمير ملعقة ملح كوب جبن ال...
# 46   وصفات فتافيت  ملاعق دقيق ملاعق سكر بودرة جرام سمن مذاب ملعقة...
# 47   وصفات فتافيت  كوب كوكيز الشوكولاتة المفتتة صفار بيض كوب حليب...
# 48   وصفات فتافيت  كوب تمر كوب لوز بياض بيض كوب سكر بودرة ملعقة ب...
# 49   Unknown Chef  جرام زبدة جرام سكر جرام سكر بني جرام شراب الذر...
#
#                                               recipes
# 0   يحمى الفرن إلى درجة مئوية بدون مروحة تغلف قاعد...
# 1   يثبت الرف الشبكي في وسط الفرن يسخن الفرن إلى د...
# 2   يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3   يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5   تخفق الزبدة مع السكر حتى يتكون خليطا خفيفا وزغ...
# 6   لعمل الصوص يرفع السكر مع الماء على النار درجة ...
# 7   تنخل المكونات الجافة معا فيما عدا السكر توضع ب...
# 8   يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9   يخفق البيض والسكر والفانيليا حتى يصبح المزيج ب...
# 10  يخلط السميد والطحين والكركم والزعفران والباكين...
# 11  تخفق الزبدة مع السكر والفانيليا حتى يصبح المزي...
# 12  يسخن الفرن لدرجة حرارة يستعمل قالب ذو فتحة في ...
# 13  يسخن الفرن على درجة حرارة درجة مئوية في وعاء ك...
# 14  يضرب في وعاء معجون الفستق الحلبي والجلوكوز لمد...
# 15  في وعاء عميق نقوم بوضع اللبنة والحليب ونخلطهم ...
# 16  يسخن الفرن إلى درجة مئوية غلف صينية الخبز بورق...
# 17  نقطع البصل إلى قطع صغيرة ثم فى وعاء متوسط الحج...
# 18  لتحضير العجين نذيب الخميرة في الماء الدافئ و ت...
# 19  تذوب الخميرة في الماء الدافئ وتترك لمدة دقائق ...
# 20  تذاب الخميرة في الماء الدافئ وتترك لمدة دقائق ...
# 21  تذاب الخميرة في الماء الدافئ و تترك لمدة دقائق...
# 22  يمزج الطحين و زيت الزيتون والخميرة والسكر والم...
# 23  ندهن الخبز بصوص البيتزا نضع جميع الخضراوات وفو...
# 24  تقطع عجينة الباف باستري إلى مستطيلات وتوضع في ...
# 25  ندهن شريحة التورتيلا بصوص البيتزا ونضع فوقه ال...
# 26  نضع الزبدة المذابة على عجين الكنافة ببطء ثم نق...
# 27  تقطع عجينة البيتزا إلى نصفين نرش الجزء الداخلي...
# 28  نضع الدقيق والخميرة و ملعقة صغيرة من الملح ومل...
# 29  تسخن ملعقة كبيرة من زيت الزيتون في مقلاة ونقوم...
# 30  تعجن مكونات العجينة بشكل جيد جدا ولمدة دقائق ع...
# 31
# 32  يقطع كل رغيف بيتا إلى مثلثات تدهن حوالي ملعقة ...
# 33  نستخدم دائما الكعكة باردة وتحفظ او تترك ملفوفة...
# 34  يسخن الفرن على حرارة درجة مئوية تبطن صينية الخ...
# 35  يخلط نوعي الدقيق والبيكنج صودا والملح في وعاء ...
# 36  يخفق السكر البودرة مع السكر الأبيض و الملح فى ...
# 37  في وعاء على النار يخلط السكر مع الشربات الخفيف...
# 38  لعمل الكوكيز تخلط كل المكونات الجافة جيدا تخفق...
# 39  لعمل الصوص في وعاء متوسط العمق على النار يخلط ...
# 40  يخلط الطحين والقرفة والملح والسكر في محضرة الط...
# 41  في محضرة الطعام يضرب دقيق اللوز مع الباكينج صو...
# 42  تخلط كل المقادير معا يوزع الخليط في أكواب ورقي...
# 43  يغلى التمر والماء والسكر معا ثم تخفض درجة الحر...
# 44  في وعاء خلاط كهربائي يوضع الزبد والدقيق والملح...
# 45  يسخن الفرن إلى درجة حرارة فهرنهايت مئوية وتدهن...
# 46  ينخل الدقيق مع الملح والفلفل والزنجبيل يفرك ال...
# 47  يصب الحليب في قدر ويوضع على النار إلى أن يبدأ ...
# 48  تخلط كل المكونات معا في وعاء يوضع ملء ملاعق طع...
# 49  تخفق الزبدة وسكر الكاسترد والسكر البني وشراب ا...

# %% [markdown]
# ### 2.2 Tokenization <a id='tokenization'></a>

# %%
from nltk.tokenize import WordPunctTokenizer

# Create a tokenizer instance
tokenizer = WordPunctTokenizer()

# Function to tokenize a single piece of text
def tokenize_text(text):
    return tokenizer.tokenize(text)

df['title_tokens_treebank'] = df['title'].apply(tokenizer.tokenize)
df['properties_tokens_treebank'] = df['properties'].apply(tokenizer.tokenize)
df['ingredients_tokens_treebank'] = df['ingredients'].apply(tokenizer.tokenize)
df['recipes_tokens_treebank'] = df['recipes'].apply(tokenizer.tokenize)

df.head()
# Out:
#                         _id                title properties           chef  \
# 0  66135d7bccad4da1905a3eb0  تشيز كيك قليل الدسم       سهلة  ليلى فتح الله
# 1  66135d7bccad4da1905a3eb1    كيك الموز بالتوفي       سهلة    منال العالم
# 2  66135d7bccad4da1905a3eb2   كيك ماربل بالكاكاو       سهلة    منال العالم
# 3  66135d7bccad4da1905a3eb3     كيك القرع واللوز       سهلة   وصفات فتافيت
# 4  66135d7bccad4da1905a3eb4         كعكة الجواهر       سهلة   وصفات فتافيت
#
#                                          ingredients  \
# 0  جرام بسكويت عادي جرام زبدة جرام جبنة الكريم جر...
# 1  كوب دقيق ملعقة كبيرة بيكنج باودر ملعقة صغيرة م...
# 2  كوب دقيق ملعقة صغيرة بيكنج باودر ملعقة صغيرة م...
# 3  جرام دقيق اللوز جرام طحين متعدد الاستعمالات مل...
# 4  عبوة تحتوي على أنواع مختلفة من الجيلاتين المنك...
#
#                                              recipes  \
# 0  يحمى الفرن إلى درجة مئوية بدون مروحة تغلف قاعد...
# 1  يثبت الرف الشبكي في وسط الفرن يسخن الفرن إلى د...
# 2  يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3  يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
#
#       title_tokens_treebank properties_tokens_treebank  \
# 0  [تشيز, كيك, قليل, الدسم]                     [سهلة]
# 1     [كيك, الموز, بالتوفي]                     [سهلة]
# 2    [كيك, ماربل, بالكاكاو]                     [سهلة]
# 3      [كيك, القرع, واللوز]                     [سهلة]
# 4           [كعكة, الجواهر]                     [سهلة]
#
#                          ingredients_tokens_treebank  \
# 0  [جرام, بسكويت, عادي, جرام, زبدة, جرام, جبنة, ا...
# 1  [كوب, دقيق, ملعقة, كبيرة, بيكنج, باودر, ملعقة,...
# 2  [كوب, دقيق, ملعقة, صغيرة, بيكنج, باودر, ملعقة,...
# 3  [جرام, دقيق, اللوز, جرام, طحين, متعدد, الاستعم...
# 4  [عبوة, تحتوي, على, أنواع, مختلفة, من, الجيلاتي...
#
#                              recipes_tokens_treebank
# 0  [يحمى, الفرن, إلى, درجة, مئوية, بدون, مروحة, ت...
# 1  [يثبت, الرف, الشبكي, في, وسط, الفرن, يسخن, الف...
# 2  [يحضر, قالب, ذو, فتحة, من, الوسط, سعة, كوب, يد...
# 3  [يخلط, دقيق, اللوز, والطحين, متعدد, الاستعمالا...
# 4                                                 []

# %% [markdown]
# ### 2.3 Stop words <a id='stop-words'></a>

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Download the stopwords list for Arabic
nltk.download('stopwords')

# Load Arabic stopwords
arabic_stop_words = set(stopwords.words('arabic'))

# Function to tokenize a single piece of text and remove Arabic stopwords
def tokenize_and_remove_stopwords(text):
    # Tokenize the text
    word_tokens = word_tokenize(text)
    # Remove Arabic stopwords
    filtered_sentence = [w for w in word_tokens if not w in arabic_stop_words]
    return filtered_sentence

# Function to remove stopwords from a piece of text
def remove_stopwords(text, stop_words):
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
    return ' '.join(filtered_sentence)

# Assuming df is your DataFrame with columns 'title', 'properties', 'ingredients', and 'recipes'

# Apply remove_stopwords function to each column
df['title_tokens'] = df['title'].apply(lambda x: remove_stopwords(x, arabic_stop_words))
df['properties_tokens'] = df['properties'].apply(lambda x: remove_stopwords(x, arabic_stop_words))
df['ingredients_tokens'] = df['ingredients'].apply(lambda x: remove_stopwords(x, arabic_stop_words))
df['recipes_tokens'] = df['recipes'].apply(lambda x: remove_stopwords(x, arabic_stop_words))

print(df[['recipes', 'recipes_tokens']].head(20))
# Out:
#                                               recipes  \
# 0   يحمى الفرن إلى درجة مئوية بدون مروحة تغلف قاعد...
# 1   يثبت الرف الشبكي في وسط الفرن يسخن الفرن إلى د...
# 2   يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3   يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5   تخفق الزبدة مع السكر حتى يتكون خليطا خفيفا وزغ...
# 6   لعمل الصوص يرفع السكر مع الماء على النار درجة ...
# 7   تنخل المكونات الجافة معا فيما عدا السكر توضع ب...
# 8   يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9   يخفق البيض والسكر والفانيليا حتى يصبح المزيج ب...
# 10  يخلط السميد والطحين والكركم والزعفران والباكين...
# 11  تخفق الزبدة مع السكر والفانيليا حتى يصبح المزي...
# 12  يسخن الفرن لدرجة حرارة يستعمل قالب ذو فتحة في ...
# 13  يسخن الفرن على درجة حرارة درجة مئوية في وعاء ك...
# 14  يضرب في وعاء معجون الفستق الحلبي والجلوكوز لمد...
# 15  في وعاء عميق نقوم بوضع اللبنة والحليب ونخلطهم ...
# 16  يسخن الفرن إلى درجة مئوية غلف صينية الخبز بورق...
# 17  نقطع البصل إلى قطع صغيرة ثم فى وعاء متوسط الحج...
# 18  لتحضير العجين نذيب الخميرة في الماء الدافئ و ت...
# 19  تذوب الخميرة في الماء الدافئ وتترك لمدة دقائق ...
#
#                                        recipes_tokens
# 0   يحمى الفرن درجة مئوية بدون مروحة تغلف قاعدة قا...
# 1   يثبت الرف الشبكي وسط الفرن يسخن الفرن درجة حرا...
# 2   يحضر قالب فتحة الوسط سعة كوب يدهن القالب بقليل...
# 3   يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5   تخفق الزبدة السكر يتكون خليطا خفيفا وزغبا يضاف...
# 6   لعمل الصوص يرفع السكر الماء النار درجة حرارة م...
# 7   تنخل المكونات الجافة معا السكر توضع بقية المكو...
# 8   يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9   يخفق البيض والسكر والفانيليا يصبح المزيج باهتا...
# 10  يخلط السميد والطحين والكركم والزعفران والباكين...
# 11  تخفق الزبدة السكر والفانيليا يصبح المزيج باهتا...
# 12  يسخن الفرن لدرجة حرارة يستعمل قالب فتحة الوسط ...
# 13  يسخن الفرن درجة حرارة درجة مئوية وعاء كبير يخف...
# 14  يضرب وعاء معجون الفستق الحلبي والجلوكوز لمدة د...
# 15  وعاء عميق نقوم بوضع اللبنة والحليب ونخلطهم جيد...
# 16  يسخن الفرن درجة مئوية غلف صينية الخبز بورق زبد...
# 17  نقطع البصل قطع صغيرة فى وعاء متوسط الحجم نار م...
# 18  لتحضير العجين نذيب الخميرة الماء الدافئ تترك ل...
# 19  تذوب الخميرة الماء الدافئ وتترك لمدة دقائق نضي...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 2.4 Discretization <a id='discretization'></a>

# %%
# Define the interval borders for the length of the texts
bins = [0, 180, 280, 380]  # Adjust these values according to your data
labels = ['short', 'medium', 'long']

# Discretize the length of 'ingredients'
df['ingredients_length'] = df['ingredients'].apply(len)

df['ingredients_length_category'] = pd.cut(df['ingredients_length'], bins=bins, labels=labels)

# Display the DataFrame to verify
print(df[['ingredients', 'ingredients_length', 'ingredients_length_category']].head(10))
# Out:
#                                          ingredients  ingredients_length  \
# 0  جرام بسكويت عادي جرام زبدة جرام جبنة الكريم جر...                 111
# 1  كوب دقيق ملعقة كبيرة بيكنج باودر ملعقة صغيرة م...                 244
# 2  كوب دقيق ملعقة صغيرة بيكنج باودر ملعقة صغيرة م...                 255
# 3  جرام دقيق اللوز جرام طحين متعدد الاستعمالات مل...                 347
# 4  عبوة تحتوي على أنواع مختلفة من الجيلاتين المنك...                 362
# 5  جم الدقيق جم الكاكاو البودرة ملعقة صغيرة البيك...                 198
# 6  جرام دقيق ملعقة صغيرة و نصف بيكنج باودر جرام ز...                 287
# 7  بيضة أكواب من الدقيق ملعقة صغيرة برش الليمون م...                 268
# 8  كوب دقيق ملعقة صغيرة بيكنج باودر كوب سميد ناعم...                 226
# 9  جرام زبدة كوب سكر ملعقة صغيرة فانيليا حبة بيض ...                 268
#
#   ingredients_length_category
# 0                       short
# 1                      medium
# 2                      medium
# 3                        long
# 4                        long
# 5                      medium
# 6                        long
# 7                      medium
# 8                      medium
# 9                      medium

# %% [markdown]
# ### 2.5 Normalization <a id='nor'></a>

# %%
# Normalisation du texte
def normalize_arabic_text(text):
    text = re.sub(r'[\u0617-\u061A\u064B-\u0652]', '', text)
    text = re.sub(r'أ|إ|آ', 'ا', text)
    return text


df['recipes_norm'] = df['recipes'].apply(normalize_arabic_text)
print(df[['recipes', 'recipes_norm']].head(20))
# Out:
#                                               recipes  \
# 0   يحمى الفرن إلى درجة مئوية بدون مروحة تغلف قاعد...
# 1   يثبت الرف الشبكي في وسط الفرن يسخن الفرن إلى د...
# 2   يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3   يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5   تخفق الزبدة مع السكر حتى يتكون خليطا خفيفا وزغ...
# 6   لعمل الصوص يرفع السكر مع الماء على النار درجة ...
# 7   تنخل المكونات الجافة معا فيما عدا السكر توضع ب...
# 8   يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9   يخفق البيض والسكر والفانيليا حتى يصبح المزيج ب...
# 10  يخلط السميد والطحين والكركم والزعفران والباكين...
# 11  تخفق الزبدة مع السكر والفانيليا حتى يصبح المزي...
# 12  يسخن الفرن لدرجة حرارة يستعمل قالب ذو فتحة في ...
# 13  يسخن الفرن على درجة حرارة درجة مئوية في وعاء ك...
# 14  يضرب في وعاء معجون الفستق الحلبي والجلوكوز لمد...
# 15  في وعاء عميق نقوم بوضع اللبنة والحليب ونخلطهم ...
# 16  يسخن الفرن إلى درجة مئوية غلف صينية الخبز بورق...
# 17  نقطع البصل إلى قطع صغيرة ثم فى وعاء متوسط الحج...
# 18  لتحضير العجين نذيب الخميرة في الماء الدافئ و ت...
# 19  تذوب الخميرة في الماء الدافئ وتترك لمدة دقائق ...
#
#                                          recipes_norm
# 0   يحمى الفرن الى درجة مئوية بدون مروحة تغلف قاعد...
# 1   يثبت الرف الشبكي في وسط الفرن يسخن الفرن الى د...
# 2   يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3   يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5   تخفق الزبدة مع السكر حتى يتكون خليطا خفيفا وزغ...
# 6   لعمل الصوص يرفع السكر مع الماء على النار درجة ...
# 7   تنخل المكونات الجافة معا فيما عدا السكر توضع ب...
# 8   يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9   يخفق البيض والسكر والفانيليا حتى يصبح المزيج ب...
# 10  يخلط السميد والطحين والكركم والزعفران والباكين...
# 11  تخفق الزبدة مع السكر والفانيليا حتى يصبح المزي...
# 12  يسخن الفرن لدرجة حرارة يستعمل قالب ذو فتحة في ...
# 13  يسخن الفرن على درجة حرارة درجة مئوية في وعاء ك...
# 14  يضرب في وعاء معجون الفستق الحلبي والجلوكوز لمد...
# 15  في وعاء عميق نقوم بوضع اللبنة والحليب ونخلطهم ...
# 16  يسخن الفرن الى درجة مئوية غلف صينية الخبز بورق...
# 17  نقطع البصل الى قطع صغيرة ثم فى وعاء متوسط الحج...
# 18  لتحضير العجين نذيب الخميرة في الماء الدافئ و ت...
# 19  تذوب الخميرة في الماء الدافئ وتترك لمدة دقائق ...

# %% [markdown]
# ### 2.6  Stemming and Lemmatization <a id='SL'></a>

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import nltk


# Download the WordNet corpus for stemming
nltk.download('wordnet')

# Load Arabic stopwords
arabic_stop_words = set(stopwords.words('arabic'))

# Create an object of class PorterStemmer
porter = PorterStemmer()

# Function to tokenize a single piece of text, remove Arabic stopwords, and perform stemming
def tokenize_remove_stopwords_and_stem(text):
    # Tokenize the text
    word_tokens = word_tokenize(text)
    # Remove Arabic stopwords
    filtered_sentence = [w for w in word_tokens if not w in arabic_stop_words]
    # Perform stemming
    stemmed_words = [porter.stem(w) for w in filtered_sentence]
    return stemmed_words

# Tokenize, remove Arabic stopwords, and perform stemming for each column
df['title_tokens_stemmed'] = df['title'].apply(tokenize_remove_stopwords_and_stem)
df['properties_tokens_stemmed'] = df['properties'].apply(tokenize_remove_stopwords_and_stem)
df['ingredients_tokens_stemmed'] = df['ingredients'].apply(tokenize_remove_stopwords_and_stem)
df['recipes_tokens_stemmed'] = df['recipes'].apply(tokenize_remove_stopwords_and_stem)

# Concatenate stemmed tokens from all columns
all_stemmed_tokens = df['title_tokens_stemmed'] + df['properties_tokens_stemmed'] + df['ingredients_tokens_stemmed'] + df['recipes_tokens_stemmed']
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer
import nltk

# Download the WordNet corpus for lemmatization
nltk.download('wordnet')

# Create an object of class WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Function to tokenize a single piece of text, remove Arabic stopwords, and perform lemmatization
def tokenize_remove_stopwords_and_lemmatize(text):
    # Tokenize the text
    word_tokens = word_tokenize(text)
    # Remove Arabic stopwords
    filtered_sentence = [w for w in word_tokens if not w in arabic_stop_words]
    # Perform lemmatization
    lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_sentence]
    return lemmatized_words

# Tokenize, remove Arabic stopwords, and perform lemmatization for each column
df['title_tokens_lemmatized'] = df['title'].apply(tokenize_remove_stopwords_and_lemmatize)
df['properties_tokens_lemmatized'] = df['properties'].apply(tokenize_remove_stopwords_and_lemmatize)
df['ingredients_tokens_lemmatized'] = df['ingredients'].apply(tokenize_remove_stopwords_and_lemmatize)
df['recipes_tokens_lemmatized'] = df['recipes'].apply(tokenize_remove_stopwords_and_lemmatize)

# Concatenate lemmatized tokens from all columns
all_lemmatized_tokens = df['title_tokens_lemmatized'] + df['properties_tokens_lemmatized'] + df['ingredients_tokens_lemmatized'] + df['recipes_tokens_lemmatized']
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Print stemmed tokens
print("Stemmed Tokens:")
print(all_stemmed_tokens)

# Print lemmatized tokens
print("\nLemmatized Tokens:")
print(all_lemmatized_tokens)
# Out:
# Stemmed Tokens:
# 0     [تشيز, كيك, قليل, الدسم, سهلة, جرام, بسكويت, ع...
# 1     [كيك, الموز, بالتوفي, سهلة, كوب, دقيق, ملعقة, ...
# 2     [كيك, ماربل, بالكاكاو, سهلة, كوب, دقيق, ملعقة,...
# 3     [كيك, القرع, واللوز, سهلة, جرام, دقيق, اللوز, ...
# 4     [كعكة, الجواهر, سهلة, عبوة, تحتوي, أنواع, مختل...
# 5     [كعكة, البلاك, فورست, سهلة, جم, الدقيق, جم, ال...
# 6     [مخبوز, البانوفى, بالموز, كيك, متوسطة, جرام, د...
# 7     [كيك, التمر, سهلة, بيضة, أكواب, الدقيق, ملعقة,...
# 8     [كيكة, السميد, سهلة, كوب, دقيق, ملعقة, صغيرة, ...
# 9     [كاب, كيك, بشوكولاتة, فيريرو, متوسطة, جرام, زب...
# 10    [سفوف, بالزعفران, سهلة, جرام, سميد, جرام, طحين...
# 11    [كيك, طبقات, آيس, كريم, متوسطة, جرام, زبدة, كو...
# 12    [كيك, مابدك, سهلة, كوب, دقيق, ملعقة, كبيرة, بي...
# 13    [كيندا, كيك, متقدمة, بياض, بيض, كوب, سكر, ابيض...
# 14    [كب, كيك, بالفستق, الحلبي, سهلة, جرام, معجون, ...
# 15    [بيتزا, التوست, سهلة, قطع, توست, كوب, لبنة, ما...
# 16    [بيتزا, الدجاج, متوسطة, عجينة, بيتزا, جاهزة, ك...
# 17    [بيتزا, الأم, العربية, متوسطة, كوب, الماء, الد...
# 18    [بيتزا, البحر, المتوسط, سهلة, لعجينة, البيتزا,...
# 19    [بيتزا, دجاج, كاجون, وصوص, سهلة, عجينة, البيتز...
# 20    [بيتزا, مارغريتا, سهلة, طحين, الذرة, طماطم, مق...
# 21    [بيتزا, البصل, المكرمل, والأنشوفة, سهلة, عجينة...
# 22    [بيتزا, الهليون, والريكوتا, سهلة, لعجين, البيت...
# 23    [بيتزا, بالخبز, العربي, سهلة, شريحة, خبز, عربي...
# 24    [بيتزا, جيوب, البيبروني, سهلة, شريحة, باف, باس...
# 25    [بيتزا, الكاساديا, سهلة, شريحة, تورتيلا, القمح...
# 26    [كنافة, ذهبية, بالمانجو, والكريمه, سهلة, جرام,...
# 27    [فطيرة, الكفتة, سهلة, جم, عجينة, بيتزا, ملعقة,...
# 28    [بيتزا, دبل, تشيز, برجر, سهلة, جم, طحين, ملعقة...
# 29    [مناقيش, حلوم, وفلفل, سهلة, ملعقة, كبيرة, زيت,...
# 30    [رقاقات, الجبنة, متوسطة, العجين, كوب, طحين, كو...
# 31    [تغطية, الكعكة, بطبقة, الفندان, سهلة, أقراص, س...
# 32    [لفائف, البيتزا, سهلة, كوب, أوراق, الريحان, فص...
# 33    [حشو, وتغطية, طبقات, الكيك, سهلة, أدوات, تشكيل...
# 34    [كوكيز, الزبدة, متوسطة, كوب, طحين, متعدد, الاس...
# 35    [كوكيز, رقائق, الشوكولاتة, سهلة, كوب, الدقيق, ...
# 36    [كوكيز, قوس, قزح, متوسطة, كوب, نصف, سكر, ملعقة...
# 37    [كوكيز, زبدة, الفول, السوداني, متوسطة, كوب, سك...
# 38    [كوكيز, الشيكولاتة, بالنعناع, متوسطة, كوب, زبد...
# 39    [كوكيز, البيتزا, متوسطة, كوب, نصف, سكر, ملعقة,...
# 40    [كوكيز, بالزبدة, والبندق, سهلة, جرام, طحين, مت...
# 41    [سكونز, بالجوز, وتوت, العليق, سهلة, كوب, دقيق,...
# 42    [كوكيز, صحي, سهلة, كوب, شوفان, كوب, لوز, كوب, ...
# 43    [كوكيز, بقطرات, التمر, سهلة, كوب, زبد, كوب, سك...
# 44    [كوكيز, التمر, سهلة, كوب, زبد, كوب, دقيق, عادي...
# 45    [سكون, البارميزان, الصغيرة, سهلة, ملعقة, زبدة,...
# 46    [كوكيز, الزنجبيل, سهلة, ملاعق, دقيق, ملاعق, سك...
# 47    [كوكيز, وكريمة, سهلة, كوب, كوكيز, الشوكولاتة, ...
# 48    [كوكيز, التمر, اللينة, سهلة, كوب, تمر, كوب, لو...
# 49    [كوكيز, بالأوريو, والكرز, سهلة, جرام, زبدة, جر...
# dtype: object
#
# Lemmatized Tokens:
# 0     [تشيز, كيك, قليل, الدسم, سهلة, جرام, بسكويت, ع...
# 1     [كيك, الموز, بالتوفي, سهلة, كوب, دقيق, ملعقة, ...
# 2     [كيك, ماربل, بالكاكاو, سهلة, كوب, دقيق, ملعقة,...
# 3     [كيك, القرع, واللوز, سهلة, جرام, دقيق, اللوز, ...
# 4     [كعكة, الجواهر, سهلة, عبوة, تحتوي, أنواع, مختل...
# 5     [كعكة, البلاك, فورست, سهلة, جم, الدقيق, جم, ال...
# 6     [مخبوز, البانوفى, بالموز, كيك, متوسطة, جرام, د...
# 7     [كيك, التمر, سهلة, بيضة, أكواب, الدقيق, ملعقة,...
# 8     [كيكة, السميد, سهلة, كوب, دقيق, ملعقة, صغيرة, ...
# 9     [كاب, كيك, بشوكولاتة, فيريرو, متوسطة, جرام, زب...
# 10    [سفوف, بالزعفران, سهلة, جرام, سميد, جرام, طحين...
# 11    [كيك, طبقات, آيس, كريم, متوسطة, جرام, زبدة, كو...
# 12    [كيك, مابدك, سهلة, كوب, دقيق, ملعقة, كبيرة, بي...
# 13    [كيندا, كيك, متقدمة, بياض, بيض, كوب, سكر, ابيض...
# 14    [كب, كيك, بالفستق, الحلبي, سهلة, جرام, معجون, ...
# 15    [بيتزا, التوست, سهلة, قطع, توست, كوب, لبنة, ما...
# 16    [بيتزا, الدجاج, متوسطة, عجينة, بيتزا, جاهزة, ك...
# 17    [بيتزا, الأم, العربية, متوسطة, كوب, الماء, الد...
# 18    [بيتزا, البحر, المتوسط, سهلة, لعجينة, البيتزا,...
# 19    [بيتزا, دجاج, كاجون, وصوص, سهلة, عجينة, البيتز...
# 20    [بيتزا, مارغريتا, سهلة, طحين, الذرة, طماطم, مق...
# 21    [بيتزا, البصل, المكرمل, والأنشوفة, سهلة, عجينة...
# 22    [بيتزا, الهليون, والريكوتا, سهلة, لعجين, البيت...
# 23    [بيتزا, بالخبز, العربي, سهلة, شريحة, خبز, عربي...
# 24    [بيتزا, جيوب, البيبروني, سهلة, شريحة, باف, باس...
# 25    [بيتزا, الكاساديا, سهلة, شريحة, تورتيلا, القمح...
# 26    [كنافة, ذهبية, بالمانجو, والكريمه, سهلة, جرام,...
# 27    [فطيرة, الكفتة, سهلة, جم, عجينة, بيتزا, ملعقة,...
# 28    [بيتزا, دبل, تشيز, برجر, سهلة, جم, طحين, ملعقة...
# 29    [مناقيش, حلوم, وفلفل, سهلة, ملعقة, كبيرة, زيت,...
# 30    [رقاقات, الجبنة, متوسطة, العجين, كوب, طحين, كو...
# 31    [تغطية, الكعكة, بطبقة, الفندان, سهلة, أقراص, س...
# 32    [لفائف, البيتزا, سهلة, كوب, أوراق, الريحان, فص...
# 33    [حشو, وتغطية, طبقات, الكيك, سهلة, أدوات, تشكيل...
# 34    [كوكيز, الزبدة, متوسطة, كوب, طحين, متعدد, الاس...
# 35    [كوكيز, رقائق, الشوكولاتة, سهلة, كوب, الدقيق, ...
# 36    [كوكيز, قوس, قزح, متوسطة, كوب, نصف, سكر, ملعقة...
# 37    [كوكيز, زبدة, الفول, السوداني, متوسطة, كوب, سك...
# 38    [كوكيز, الشيكولاتة, بالنعناع, متوسطة, كوب, زبد...
# 39    [كوكيز, البيتزا, متوسطة, كوب, نصف, سكر, ملعقة,...
# 40    [كوكيز, بالزبدة, والبندق, سهلة, جرام, طحين, مت...
# 41    [سكونز, بالجوز, وتوت, العليق, سهلة, كوب, دقيق,...
# 42    [كوكيز, صحي, سهلة, كوب, شوفان, كوب, لوز, كوب, ...
# 43    [كوكيز, بقطرات, التمر, سهلة, كوب, زبد, كوب, سك...
# 44    [كوكيز, التمر, سهلة, كوب, زبد, كوب, دقيق, عادي...
# 45    [سكون, البارميزان, الصغيرة, سهلة, ملعقة, زبدة,...
# 46    [كوكيز, الزنجبيل, سهلة, ملاعق, دقيق, ملاعق, سك...
# 47    [كوكيز, وكريمة, سهلة, كوب, كوكيز, الشوكولاتة, ...
# 48    [كوكيز, التمر, اللينة, سهلة, كوب, تمر, كوب, لو...
# 49    [كوكيز, بالأوريو, والكرز, سهلة, جرام, زبدة, جر...
# dtype: object

# %% [markdown]
# ## 3. Parts of Speech (POS) <a id='part'></a>

# %%
# Assuming df is your DataFrame and 'recipes' is the column with text data
import stanza

# Load the POS tagging model for Arabic
nlp = stanza.Pipeline(lang='ar', processors='tokenize,pos')

# This function uses the loaded model to tag tokens
def pos_tag_arabic(tokens):
    doc = nlp(' '.join(tokens))
    return [(word.text, word.pos) for sent in doc.sentences for word in sent.words]

# Tokenize the 'recipes' column
df['recipes_tokenized'] = df['recipes'].apply(lambda x: x.split())

# Apply the POS tagging function to the tokenized text
df['recipes_pos_tags'] = df['recipes_tokenized'].apply(pos_tag_arabic)

# Check the results
print(df[['recipes', 'recipes_pos_tags']].head(10))
# Out:
# 2024-04-08 03:01:47 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-08 03:01:48 INFO: Downloaded file to C:\Users\Administrator\stanza_resources\resources.json
# 2024-04-08 03:01:48 WARNING: Language ar package default expects mwt, which has been added
# 2024-04-08 03:01:48 INFO: Loading these models for language: ar (Arabic):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | padt        |
# | mwt       | padt        |
# | pos       | padt_charlm |
# ===========================
#
# 2024-04-08 03:01:48 INFO: Using device: cpu
# 2024-04-08 03:01:48 INFO: Loading: tokenize
# 2024-04-08 03:01:50 INFO: Loading: mwt
# 2024-04-08 03:01:50 INFO: Loading: pos
# 2024-04-08 03:01:51 INFO: Done loading processors!
#                                              recipes  \
# 0  يحمى الفرن إلى درجة مئوية بدون مروحة تغلف قاعد...
# 1  يثبت الرف الشبكي في وسط الفرن يسخن الفرن إلى د...
# 2  يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3  يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5  تخفق الزبدة مع السكر حتى يتكون خليطا خفيفا وزغ...
# 6  لعمل الصوص يرفع السكر مع الماء على النار درجة ...
# 7  تنخل المكونات الجافة معا فيما عدا السكر توضع ب...
# 8  يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9  يخفق البيض والسكر والفانيليا حتى يصبح المزيج ب...
#
#                                     recipes_pos_tags
# 0  [(يحمى, VERB), (الفرن, NOUN), (إلى, ADP), (درج...
# 1  [(يثبت, VERB), (الرف, NOUN), (الشبكي, ADJ), (ف...
# 2  [(يحضر, VERB), (قالب, NOUN), (ذو, DET), (فتحة,...
# 3  [(يخلط, VERB), (دقيق, NOUN), (اللوز, NOUN), (و...
# 4                                                 []
# 5  [(تخفق, VERB), (الزبدة, NOUN), (مع, ADP), (الس...
# 6  [(لعمل, NOUN), (الصوص, NOUN), (يرفع, VERB), (ا...
# 7  [(تنخل, VERB), (المكونات, NOUN), (الجافة, ADJ)...
# 8  [(يسخن, VERB), (الفرن, NOUN), (ل, ADP), (درجة,...
# 9  [(يخفق, VERB), (البيض, NOUN), (و, CCONJ), (الس...

# %% [markdown]
# ## 4. Named Entity Recognition(NER) <a id='ner'></a>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# Define function to apply NER on text
def apply_ner(text):
    doc = nlp(text)
    return [(ent.text, ent.label_) for ent in doc.ents]

# Apply NER to the 'recipes' column
df['recipes_ner'] = df['recipes'].apply(apply_ner)

# Print the results
print(df[['recipes', 'recipes_ner']].head(10))
# Out:
#                                              recipes  \
# 0  يحمى الفرن إلى درجة مئوية بدون مروحة تغلف قاعد...
# 1  يثبت الرف الشبكي في وسط الفرن يسخن الفرن إلى د...
# 2  يحضر قالب ذو فتحة من الوسط سعة كوب يدهن القالب...
# 3  يخلط دقيق اللوز والطحين متعدد الاستعمالات والب...
# 4
# 5  تخفق الزبدة مع السكر حتى يتكون خليطا خفيفا وزغ...
# 6  لعمل الصوص يرفع السكر مع الماء على النار درجة ...
# 7  تنخل المكونات الجافة معا فيما عدا السكر توضع ب...
# 8  يسخن الفرن لدرجة حرارة يحضر قالب مستدير مقاس ب...
# 9  يخفق البيض والسكر والفانيليا حتى يصبح المزيج ب...
#
#                                          recipes_ner
# 0  [(كيك قياس, ORG), (الزبدة, ORG), (الذائبة ويضر...
# 1  [(يثبت الرف, PERSON), (الزبدة, NORP), (ورق, OR...
# 2  [(يحضر قالب ذو فتحة, ORG), (السمن, GPE), (ورق,...
# 3  [(الزبدة والسكر, PERSON), (يضاف, GPE), (المقاد...
# 4                                                 []
# 5  [(تخفق الزبدة, PERSON), (السكر, GPE), (يضاف, G...
# 6  [(السكر مع, ORG), (النار, GPE), (يترك, GPE), (...
# 7  [(وعاء منفصل, ORG), (تمزج يضاف الخليط الجاف إل...
# 8  [(يسخن الفرن لدرجة حرارة يحضر قالب, ORG), (بال...
# 9  [(والسكر والفانيليا, PERSON), (يضاف, GPE), (كل...

# %% [markdown]
# ## 5. Lab Reflection <a id='lab'></a>

# %% [markdown]
# In this lab, I learned about web scraping, which is the process of extracting data from websites. We used BeautifulSoup, a Python library, to scrape recipe data from the Fatafeat website. This involved parsing the HTML content of web pages to extract recipe titles, properties, chefs, links, ingredients, and recipes. We wrote a function called `scrape_recipe_data` to automate this process for cakes, pizzas, and cookies. The scraped data was then stored in MongoDB for easy access. Alongside web scraping, I also explored various natural language processing (NLP) techniques like text cleaning, tokenization, and named entity recognition (NER). This hands-on experience has enriched my understanding of data collection and analysis methods.
